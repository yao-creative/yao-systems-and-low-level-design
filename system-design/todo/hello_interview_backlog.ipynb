# %% [markdown]
# # Hello Interview System Design TODO
#
# Backlog generated from the Hello Interview system design problem breakdown index.
#
# Use this notebook as the queue, then split any problem into its own working notebook when you actually practice it.

# %% [markdown]
# ## Queue
#
# | Status | Problem | Difficulty | Source |
# | --- | --- | --- | --- |
# | TODO | Bitly | Easy | https://www.hellointerview.com/learn/system-design/problem-breakdowns/bitly |
# | TODO | Dropbox | Easy | https://www.hellointerview.com/learn/system-design/problem-breakdowns/dropbox |
# | TODO | Local Delivery Service | Easy | https://www.hellointerview.com/learn/system-design/problem-breakdowns/gopuff |
# | TODO | Ticketmaster | Medium | https://www.hellointerview.com/learn/system-design/problem-breakdowns/ticketmaster |
# | TODO | FB News Feed | Medium | https://www.hellointerview.com/learn/system-design/problem-breakdowns/fb-news-feed |
# | TODO | Tinder | Medium | https://www.hellointerview.com/learn/system-design/problem-breakdowns/tinder |
# | TODO | LeetCode | Medium | https://www.hellointerview.com/learn/system-design/problem-breakdowns/leetcode |
# | TODO | WhatsApp | Medium | https://www.hellointerview.com/learn/system-design/problem-breakdowns/whatsapp |
# | TODO | Rate Limiter | Medium | https://www.hellointerview.com/learn/system-design/problem-breakdowns/distributed-rate-limiter |
# | TODO | FB Live Comments | Medium | https://www.hellointerview.com/learn/system-design/problem-breakdowns/fb-live-comments |
# | TODO | FB Post Search | Medium | https://www.hellointerview.com/learn/system-design/problem-breakdowns/fb-post-search |
# | TODO | YouTube Top K | Hard | https://www.hellointerview.com/learn/system-design/problem-breakdowns/top-k |
# | TODO | Uber | Hard | https://www.hellointerview.com/learn/system-design/problem-breakdowns/uber |
# | TODO | YouTube | Hard | https://www.hellointerview.com/learn/system-design/problem-breakdowns/youtube |
# | TODO | Web Crawler | Hard | https://www.hellointerview.com/learn/system-design/problem-breakdowns/web-crawler |
# | TODO | Ad Click Aggregator | Hard | https://www.hellointerview.com/learn/system-design/problem-breakdowns/ad-click-aggregator |

# %% [markdown]
# ## Suggested Order
#
# 1. Bitly
# 2. Dropbox
# 3. Rate Limiter
# 4. Ticketmaster
# 5. WhatsApp
# 6. FB News Feed
# 7. Tinder
# 8. LeetCode
# 9. FB Live Comments
# 10. FB Post Search
# 11. YouTube Top K
# 12. Web Crawler
# 13. YouTube
# 14. Uber
# 15. Ad Click Aggregator
# 16. Local Delivery Service

# %% [markdown]
# ## Working Rule
#
# When you start one problem, create a dedicated notebook next to this backlog with this naming pattern:
#
# - `01-bitly.ipynb`
# - `02-dropbox.ipynb`
# - `03-rate-limiter.ipynb`
#
# Recommended notebook sections:
#
# 1. Clarifying questions
# 2. Functional and non-functional requirements
# 3. Back-of-the-envelope estimates
# 4. API or interface sketch
# 5. Data model and invariants
# 6. High-level design
# 7. Read and write paths
# 8. Bottlenecks and failure modes
# 9. Socratic critique questions
# 10. Revised design
# 11. Frontier AI applications
# 12. Variants and challenge questions
